# %% [markdown]
# # EduPro Course Demand & Revenue Forecasting - Data Cleaning
# This notebook cleans the raw data (removes duplicates, handles missing values, corrects datatypes, and filters out anomalies).

# %%
import os
import sys
sys.path.append('..')
from src.data.cleaning import clean_and_save_data

raw_excel = r"../data/raw/EduPro_Dataset.xlsx"
processed_dir = r"../data/processed"

courses_clean, teachers_clean, transactions_clean = clean_and_save_data(raw_excel, processed_dir)
# Out:
# Loading data from ../data/raw/EduPro_Dataset.xlsx...
# Sheets found: ['Users', 'Teachers', 'Courses', 'Transactions']
# Cleaning Courses...
# Cleaning Teachers...
# Cleaning Transactions...
# Cleaned CSVs saved to ../data/processed
# Courses cleaned shape: (60, 8)
# Teachers cleaned shape: (60, 7)
# Transactions cleaned shape: (10000, 7)

# %% [markdown]
# ### Inspecting cleaned tables

# %%
print("Cleaned Courses:")
display(courses_clean.head(3))
print("Cleaned Teachers:")
display(teachers_clean.head(3))
print("Cleaned Transactions:")
display(transactions_clean.head(3))
# Out:
# Cleaned Courses:
#   CourseID         CourseName CourseCategory CourseType   CourseLevel  \
# 0  CR00001      Python Basics    Programming       Paid      Beginner
# 1  CR00002   Java Programming    Programming       Free  Intermediate
# 2  CR00003  C++ for Beginners    Programming       Free      Beginner
#
#    CoursePrice  CourseDuration  CourseRating
# 0       472.28           11.00          4.74
# 1         0.00           37.70          2.43
# 2         0.00           19.53          3.85
# Cleaned Teachers:
#   TeacherID         TeacherName  Age  Gender          Expertise  \
# 0   TC00001  Leonard Montgomery   44  Female      Cybersecurity
# 1   TC00002            Jill Day   32  Female  Digital Marketing
# 2   TC00003        Amber Torres   32    Male             Design
#
#    YearsOfExperience  TeacherRating
# 0                  6           3.24
# 1                  9           4.14
# 2                  4           1.56
# Cleaned Transactions:
# ...
