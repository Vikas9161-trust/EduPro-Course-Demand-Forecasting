# %% [markdown]
# # EduPro Course Demand & Revenue Forecasting - Feature Engineering
# This notebook aggregates transaction data to Course-Month level, extracts date features, bins variables, and calculates historical rolling aggregates.

# %%
import os
import sys
sys.path.append('..')
from src.data.feature_engineering import process_features

processed_dir = r"../data/processed"
merged, course_month, course_level = process_features(processed_dir)
# Out:
# Merging datasets...
# Transaction-level merged dataset saved. Shape: (10000, 20)
# Aggregating to Course-Month level...
# Calculating historical features...
# Course-Month level feature dataset saved. Shape: (720, 28)
# Aggregating to Course level...
# Course-level dataset saved. Shape: (60, 21)

# %% [markdown]
# ### Inspecting Engineered Datasets

# %%
print("Engineered Course-Month Level features shape:", course_month.shape)
print("Engineered Course-Month columns:")
print(list(course_month.columns))
display(course_month.head(5))
# Out:
# Engineered Course-Month Level features shape: (720, 28)
# Engineered Course-Month columns:
# ['CourseID', 'Year', 'Month', 'MonthlyEnrollments', 'MonthlyRevenue', 'CourseName', 'CourseCategory', 'CourseType', 'CourseLevel', 'CoursePrice', 'CourseDuration', 'CourseRating', 'TeacherID', 'TeacherName', 'Expertise', 'YearsOfExperience', 'TeacherRating', 'PriceBand', 'DurationBucket', 'RatingTier', 'ExperienceBucket', 'Quarter', 'Season', 'PastEnrollmentCount', 'AverageRevenue', 'RevenuePerEnrollment', 'AverageMonthlyRevenue', 'AverageMonthlyEnrollment']
#   CourseID  Year  Month  MonthlyEnrollments  MonthlyRevenue     CourseName  \
# 0  CR00001  2025      1                  18         8501.04  Python Basics
# 1  CR00001  2025      2                  11         5195.08  Python Basics
# 2  CR00001  2025      3                   8         3778.24  Python Basics
# 3  CR00001  2025      4                  14         6611.92  Python Basics
# ...
