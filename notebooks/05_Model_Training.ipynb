# %% [markdown]
# # EduPro Course Demand & Revenue Forecasting - Model Training
# This notebook trains baseline (Linear, Ridge, Lasso) and advanced (Random Forest, Gradient Boosting, XGBoost) models on the engineered feature dataset.

# %%
import os
import sys
sys.path.append('..')
from src.models.train import train_pipeline

data_path = r"../data/processed/feature_dataset.csv"
models_dir = r"../models"

train_pipeline(data_path, models_dir)
# Out:
# --- Training Static Models (For new course demand prediction) ---
# --- Model Evaluation Results for: Static Enrollments ---
#             Model    MAE   RMSE      R2
#             Lasso 2.8388 3.6120 -0.0371
#             Ridge 2.8568 3.6491 -0.0585
# Linear Regression 2.8603 3.6522 -0.0603
# Gradient Boosting 3.0000 3.7933 -0.1438
#           XGBoost 3.2727 3.9843 -0.2619
#     Random Forest 3.3749 4.0852 -0.3266
# Best Model Selected: Lasso with R2 of -0.0371
# --- Model Evaluation Results for: Static Revenue ---
#             Model      MAE     RMSE     R2
#             Ridge 389.9290 796.2274 0.8727
#             Lasso 390.8579 798.2172 0.8720
# Linear Regression 391.3754 798.4934 0.8719
# Gradient Boosting 349.2178 854.7082 0.8533
#     Random Forest 384.4792 892.3292 0.8401
#           XGBoost 381.6468 895.9280 0.8388
# Best Model Selected: Ridge with R2 of 0.8727
#
# Static Models successfully saved to: ../models
#
# ...
